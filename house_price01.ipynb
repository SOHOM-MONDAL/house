# %%
import pandas as pd
import matplotlib.pyplot as  plt
df = pd.read_csv('Downloads/house price.csv')
df.head()
# Out:
#                date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  02-05-2014 00:00   313000.0         3       1.50         1340      7912
# 1  02-05-2014 00:00  2384000.0         5       2.50         3650      9050
# 2  02-05-2014 00:00   342000.0         3       2.00         1930     11947
# 3  02-05-2014 00:00   420000.0         3       2.25         2000      8030
# 4  02-05-2014 00:00   550000.0         4       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
df.pop("waterfront")
#plt.scatter(X,y)
df.pop("date")
df.pop("view")
df.pop("condition")
df.pop("yr_renovated")
df.pop("yr_built")
df.pop("city")
df.pop("statezip")
df.pop("country")
df.pop("street")
df.head()
print(df.describe())
# Out:
#               price     bedrooms    bathrooms   sqft_living      sqft_lot  \
# count  4.600000e+03  4600.000000  4600.000000   4600.000000  4.600000e+03
# mean   5.519630e+05     3.400870     2.160815   2139.346957  1.485252e+04
# std    5.638347e+05     0.908848     0.783781    963.206916  3.588444e+04
# min    0.000000e+00     0.000000     0.000000    370.000000  6.380000e+02
# 25%    3.228750e+05     3.000000     1.750000   1460.000000  5.000750e+03
# 50%    4.609435e+05     3.000000     2.250000   1980.000000  7.683000e+03
# 75%    6.549625e+05     4.000000     2.500000   2620.000000  1.100125e+04
# max    2.659000e+07     9.000000     8.000000  13540.000000  1.074218e+06
#
#             floors   sqft_above  sqft_basement
# count  4600.000000  4600.000000    4600.000000
# mean      1.512065  1827.265435     312.081522
# std       0.538288   862.168977     464.137228
# min       1.000000   370.000000       0.000000
# 25%       1.000000  1190.000000       0.000000
# ...

# %%
fatures_names =['bedrooms'	,'bathrooms'	,'sqft_living'	, 'sqft_lot' ,'floors', 'sqft_above','sqft_basement']
target_names = 'price'
X =df[fatures_names]
y =df[target_names]

# %%
X.shape
# Out:
# (4600, 7)

# %%
y.shape
# Out:
# (4600,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,random_state=1)
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(X_train,y_train)
import numpy as np
mod = reg.fit(X_train, y_train)
pred = reg.predict(X_test)
pred
# Out:
# array([ 545996.02286748,  742838.35381759,  326995.06094548,
#         665127.53827496,  589975.25119583,  646152.76096221,
#         262792.07619514,  311299.04287512,  502238.93984614,
#         375598.18696154,  485802.18887121,  310045.91253925,
#         352812.34722125,  747818.51259729,  210888.80134468,
#         598153.89360812,  654157.69007613,  530336.87724911,
#         355322.7404091 ,  577366.97801616,  400587.84872236,
#         529372.05802964,  665806.83416942,  287392.673721  ,
#         701876.61107503,  424927.11888912,  245298.63499323,
#         266985.99972969,  595251.46912539,  538352.01675581,
#         433826.75130138,  675396.16798423,  258556.01940486,
#         330102.18632977,  527519.9425826 ,  485482.07945575,
#         270045.97289858,  414491.98462533,  661742.78360929,
#         269174.13981587,  967931.43984457,  388998.67774669,
#         626407.06715011,  582314.86436305,  514617.48481028,
# ...

# %%
plt.scatter(y_test,pred,marker='*')
plt.ylabel('price predicted',fontsize=20)
plt.xlabel('price test',fontsize=20)
# Out:
# Text(0.5, 0, 'price test')

# %%
from sklearn.metrics import mean_squared_error,r2_score
score = r2_score(y_test,pred)
print("Test R2 value",score)
# Out:
# Test R2 value 0.4312776210016007

# %%
mse = mean_squared_error(pred,y_test)
print("mean square error value",mse)
# Out:
# mean square error value 69357053732.16028
